# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:Samsung200146@localhost:5432/churn_project")

query = "SELECT * FROM fact_customer_profile;"

df = pd.read_sql(query, engine)

df.to_csv("../data/processed/final_ml_dataset.csv", index=False)

print("ML dataset exported successfully!")
# Out:
# ML dataset exported successfully!
